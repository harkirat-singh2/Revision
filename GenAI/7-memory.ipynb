# %% [markdown]
# # Memory

# %%
from langchain.agents import create_agent
from langchain_groq import ChatGroq
from langgraph.checkpoint.memory import InMemorySaver
import os
from dotenv import load_dotenv

load_dotenv()

# Step 1: Model object
model = ChatGroq(
    model="llama-3.3-70b-versatile",
    api_key=os.getenv("GROQ_API_KEY")
)

# Step 2: Memory (checkpointer)
memory = InMemorySaver()

# Step 3: Create agent
agent = create_agent(
    model=model,
    tools=[],  # required even if empty
    checkpointer=memory
)

# %%
from langchain_core.messages import HumanMessage, SystemMessage
config= {"configurable":{"thread_id":"test1"}}
response=agent. invoke({"messages": [HumanMessage(content="Hi my name is Krish!") ]}, config=config)
response
# Out:
# {'messages': [HumanMessage(content='Hi my name is Krish!', additional_kwargs={}, response_metadata={}, id='b16deff0-4f2a-4ac8-85c2-bee6315ff7a0'),
#   AIMessage(content="Hello Krish, it's nice to meet you. Is there something I can help you with or would you like to chat?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 26, 'prompt_tokens': 41, 'total_tokens': 67, 'completion_time': 0.047172721, 'completion_tokens_details': None, 'prompt_time': 0.001977586, 'prompt_tokens_details': None, 'queue_time': 0.289527349, 'total_time': 0.049150307}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_e65acd3773', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019d44e4-bd36-7371-8975-6498d49be55d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 41, 'output_tokens': 26, 'total_tokens': 67})]}

# %%
response=agent. invoke({"messages": [HumanMessage(content="Hi what is my name") ]}, config=config)
response
# Out:
# {'messages': [HumanMessage(content='Hi my name is Krish!', additional_kwargs={}, response_metadata={}, id='b16deff0-4f2a-4ac8-85c2-bee6315ff7a0'),
#   AIMessage(content="Hello Krish, it's nice to meet you. Is there something I can help you with or would you like to chat?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 26, 'prompt_tokens': 41, 'total_tokens': 67, 'completion_time': 0.047172721, 'completion_tokens_details': None, 'prompt_time': 0.001977586, 'prompt_tokens_details': None, 'queue_time': 0.289527349, 'total_time': 0.049150307}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_e65acd3773', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019d44e4-bd36-7371-8975-6498d49be55d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 41, 'output_tokens': 26, 'total_tokens': 67}),
# ...

# %%
from langchain_core.messages import HumanMessage, SystemMessage
config1= {"configurable":{"thread_id":"test2"}}
response=agent. invoke({"messages": [HumanMessage(content="Hi my name is Harkirat!") ]}, config=config1)
response
# Out:
# {'messages': [HumanMessage(content='Hi my name is Harkirat!', additional_kwargs={}, response_metadata={}, id='3d7fbbb9-6576-40e9-952c-bac195242fbc'),
#   AIMessage(content="Hello Harkirat, it's nice to meet you. Is there something I can help you with or would you like to chat?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 29, 'prompt_tokens': 44, 'total_tokens': 73, 'completion_time': 0.046081356, 'completion_tokens_details': None, 'prompt_time': 0.004176096, 'prompt_tokens_details': None, 'queue_time': 0.053590953, 'total_time': 0.050257452}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019d44e7-075c-7e10-bb65-6a60c534b594-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 44, 'output_tokens': 29, 'total_tokens': 73}),
# ...

# %%
response=agent. invoke({"messages": [HumanMessage(content="Hi what is my name") ]}, config=config)
response
# Out:
# {'messages': [HumanMessage(content='Hi my name is Harkirat!', additional_kwargs={}, response_metadata={}, id='3d7fbbb9-6576-40e9-952c-bac195242fbc'),
#   AIMessage(content="Hello Harkirat, it's nice to meet you. Is there something I can help you with or would you like to chat?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 29, 'prompt_tokens': 44, 'total_tokens': 73, 'completion_time': 0.046081356, 'completion_tokens_details': None, 'prompt_time': 0.004176096, 'prompt_tokens_details': None, 'queue_time': 0.053590953, 'total_time': 0.050257452}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019d44e7-075c-7e10-bb65-6a60c534b594-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 44, 'output_tokens': 29, 'total_tokens': 73}),
# ...
