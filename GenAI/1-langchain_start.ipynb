# %% [markdown]
# ### Langchain version V1

# %%
import langchain
print(langchain.__version__)
# Out:
# 1.2.13

# %%
import os
from dotenv import load_dotenv
load_dotenv()

groq_api_key = os.getenv("GROQ_API_KEY")

# %% [markdown]
# ### GenerativeAI Application

# %%
from langchain.chat_models import init_chat_model
model = init_chat_model(
    "llama-3.3-70b-versatile",
    model_provider="groq"
)

# %%
response = model.invoke("5 lines about AI")
response
# Out:
# AIMessage(content='Artificial Intelligence (AI) is a rapidly evolving field. \nIt involves the creation of intelligent machines that can think and learn. \nAI systems can analyze vast amounts of data, identify patterns, and make decisions. \nThese technologies have numerous applications, including virtual assistants and self-driving cars. \nAs AI continues to advance, it is likely to transform many aspects of our lives.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 77, 'prompt_tokens': 39, 'total_tokens': 116, 'completion_time': 0.223792861, 'completion_tokens_details': None, 'prompt_time': 0.001745796, 'prompt_tokens_details': None, 'queue_time': 0.179919074, 'total_time': 0.225538657}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_45180df409', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019d4259-ed51-7913-a9d7-4c98a21118ba-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 39, 'output_tokens': 77, 'total_tokens': 116})
