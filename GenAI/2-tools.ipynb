# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_groq import ChatGroq

model = ChatGroq(
    model ="llama-3.3-70b-versatile",
    api_key=os.getenv("GROQ_API_KEY")
)

response = model.invoke("2 points about AI")
print(response.content)
# Out:
# Here are 2 points about AI:
#
# 1. **Improved Efficiency**: AI can automate repetitive and mundane tasks, freeing up human time and increasing productivity. This can be applied to various industries, such as customer service, data analysis, and manufacturing.
# 2. **Enhanced Decision-Making**: AI can analyze vast amounts of data, identify patterns, and make predictions, allowing for more informed decision-making. This can be particularly useful in fields like healthcare, finance, and transportation, where data-driven insights can lead to better outcomes and reduced risks.
